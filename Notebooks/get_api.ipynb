# %%
import sys
sys.path.append('../CODE/LLMClient')  # Adds the directory to the Python path

# %%
from Gemini_Client import GeminiClient

# %%
DS = GeminiClient()

# %%
resp = DS.generate_text("Is this LLM working?")

# %%
resp
