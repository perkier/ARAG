# %%
import sys
sys.path.append('../CODE/LLMClient')  # Adds the directory to the Python path

# %%
from Gemini_Client import GeminiClient
from DeepSeek_Client import DeepSeekClient
from Llama_Client import LlamaClient

# %%
# DS = GeminiClient()

# %%
#DS = DeepSeekClient()

# %%
DS = LlamaClient()

# %%
resp = DS.generate_text("What's the capital of Portugal?")

# %%
resp
