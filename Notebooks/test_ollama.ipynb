# %%
import ollama
import subprocess

# %%
OLLAMA_PATH = "C:/Users/diogo/AppData/Local/Programs/"  # Replace with the actual path

# subprocess.run([OLLAMA_PATH, "pull", "meta/llama3.2"], check=True)

# %%
# Run the command
#subprocess.run([OLLAMA_PATH, "ollama", "pull", "llama3.2"], check=True)

# %%
# Generate a response from Llama 3.2
response = ollama.chat(model="llama3.2", messages=[{"role": "user", "content": "What is the meaning of life?"}])

# %%
# Run the command
#subprocess.run([OLLAMA_PATH, "ollama", "stop", "llama3.2"], check=True)

# %%
response.message.content
